# %% [markdown]
# ### Objective

# %% [raw]
# Learn how to connect to social media network (we will use Twitter as example in this assignment), and collect/preprocess/analyze its data
#
#
# Tweets Data Can be used for different purposes by marketing department and data analytics team. For example:
#
# - Compete with rivals to offer price-match gaurantee policy
# - Offer same coupons like rivals in the market place

# %% [markdown]
# ### Installation and Setup

# %% [raw]
# For this assignment you need to do the following setup first:
#
# 1.  Create an account on twitter.com.
#
# 2.  Generate authentication tokens by following the instructions here :
#     https://dev.twitter.com/oauth/overview/application-owner-access-tokens
#
# 3.  Add your tokens to the credentials.txt file.

# %% [markdown]
# ### Twitter API

# %% [raw]
# Twitter API
#
# Two APIs:
#
#     REST API: Submit HTTP requests to access specific information (tweets, friends, ...)
#     Streaming API: Open a continuous connection to Twitter to receive real-time data.
#
# These APIs are  HTTP GET request
#
#
#
#
# Here are the twitter API docs that you must familiarize yourself with
#
# https://dev.twitter.com/rest/reference/get/followers/ids
#
# https://dev.twitter.com/overview/api/twitter-libraries

# %% [raw]
# When you search in a text (tweets are text messages), often you need to be aware of something STOP WORDS.
# You could read more about stop-words here:
#
#     https://en.wikipedia.org/wiki/Stop_words

# %% [markdown]
# # Lets create twitter object and use its API. Code snippets below will show you how to use this API

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterPager

# %%
o = TwitterOAuth.read_file(r'C:\apache-tomcat-7.0.34\webapps\Assignment_5\credentials.txt')

# %%
o.access_token_key
# Out:
# '1326193147941060609-r5iWwQe6NA28dX3BKAc6M2IksDAoPk'

# %%
# Using OAuth1...
twitter = TwitterAPI(o.consumer_key,
                 o.consumer_secret,
                 o.access_token_key,
                 o.access_token_secret)

# %%
help(twitter)
# Out:
# Help on TwitterAPI in module TwitterAPI.TwitterAPI object:
#
# class TwitterAPI(builtins.object)
#  |  Access REST API or Streaming API resources.
#  |
#  |  :param consumer_key: Twitter application consumer key
#  |  :param consumer_secret: Twitter application consumer secret
#  |  :param access_token_key: Twitter application access token key
#  |  :param access_token_secret: Twitter application access token secret
#  |  :param auth_type: "oAuth1" (default) or "oAuth2"
#  |  :param proxy_url: HTTPS proxy URL string (ex. "https://USER:PASSWORD@SERVER:PORT"),
#  |                    or dict of URLs (ex. {'http':'http://SERVER', 'https':'https://SERVER'})
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type='oAuth1', proxy_url=None, api_version='1.1')
#  |      Initialize with your Twitter application credentials
#  |
#  |  request(self, resource, params=None, files=None, method_override=None, api_version=None)
#  |      Request a Twitter REST API or Streaming API resource.
#  |
#  |      :param resource: A valid Twitter endpoint (ex. "search/tweets")
#  |      :param params: Dictionary with endpoint parameters or None (default)
#  |      :param files: Dictionary with multipart-encoded file or None (default)
#  |      :param method_override: Request method to override or None (default)
#  |      :param api_version: override default API version or None (default)
#  |
#  |      :returns: TwitterResponse
#  |      :raises: TwitterConnectionError
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  CONNECTION_TIMEOUT = 5
#  |
#  |  REST_TIMEOUT = 5
#  |
#  |  STREAMING_TIMEOUT = 90
#  |
#  |  USER_AGENT = 'python-TwitterAPI'

# %%
# What can we do with this twitter object?
# builtin method `dir` tells us...
dir(twitter)
# Out:
# ['CONNECTION_TIMEOUT',
#  'REST_TIMEOUT',
#  'STREAMING_TIMEOUT',
#  'USER_AGENT',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_endpoint',
#  '_prepare_url',
#  'auth',
#  'proxies',
#  'request',
#  'version']

# %%
twitter.auth

# %%
# Get help on the `request` method using the builtin method called...`help`
help(twitter.request)
# Out:
# Help on method request in module TwitterAPI.TwitterAPI:
#
# request(resource, params=None, files=None, method_override=None, api_version=None) method of TwitterAPI.TwitterAPI.TwitterAPI instance
#     Request a Twitter REST API or Streaming API resource.
#
#     :param resource: A valid Twitter endpoint (ex. "search/tweets")
#     :param params: Dictionary with endpoint parameters or None (default)
#     :param files: Dictionary with multipart-encoded file or None (default)
#     :param method_override: Request method to override or None (default)
#     :param api_version: override default API version or None (default)
#
#     :returns: TwitterResponse
#     :raises: TwitterConnectionError

# %%
# Let's start by querying the search API
response = twitter.request('search/tweets', {'q': 'big+data'})

# %%
# What object is returned?
# builtin type method will tell us.
print(type(response))
dir(response)
# Out:
# <class 'TwitterAPI.TwitterAPI.TwitterResponse'>
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'get_iterator',
#  'get_quota',
#  'headers',
#  'json',
#  'response',
#  'status_code',
#  'stream',
#  'text']

# %%
response.json
# Out:
# <bound method TwitterResponse.json of <TwitterAPI.TwitterAPI.TwitterResponse object at 0x0000027029902390>>

# %%
response.status_code
# See https://dev.twitter.com/overview/api/response-codes
# Out:
# 200

# %%
tweets = [r for r in response]

# %%
print('found %d tweets' % len(tweets))
# Out:
# found 6 tweets

# %%
type(tweets)
# Out:
# list

# %%
type(tweets[0])
# Out:
# dict

# %%
tweets[0]
# Out:
# {'created_at': 'Sun Dec 06 06:06:04 +0000 2020',
#  'id': 1335465513334403072,
#  'id_str': '1335465513334403072',
#  'text': "RT @outromnyg: @jiaelbe it's rigged when big3 groups stop winning, it's rigged when bts wins. show us the stats, data and numbers on why ya…",
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'outromnyg',
#     'name': 'den⁷ · busy📚',
#     'id': 2937094094,
#     'id_str': '2937094094',
#     'indices': [3, 13]},
#    {'screen_name': 'jiaelbe',
#     'name': 'JACKSON BEST ERAS📌 开♡༄',
#     'id': 1230470204041367552,
#     'id_str': '1230470204041367552',
#     'indices': [15, 23]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1004232282985488384,
#   'id_str': '1004232282985488384',
#   'name': 'ᴮᴱAverie⁷',
#   'screen_name': 'spillxtheteasis',
#   'location': 'hell',
#   'description': 'armymoos follow me\U0001f92a\nif u know me irl no u dont\nshe/they',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 213,
#   'friends_count': 551,
#   'listed_count': 1,
#   'created_at': 'Wed Jun 06 05:23:28 +0000 2018',
#   'favourites_count': 60344,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 15814,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1334443759799418882/eoMxigKh_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334443759799418882/eoMxigKh_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1004232282985488384/1606991161',
#   'profile_link_color': 'F58EA8',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sun Dec 06 03:52:57 +0000 2020',
#   'id': 1335432012795006976,
#   'id_str': '1335432012795006976',
#   'text': "@jiaelbe it's rigged when big3 groups stop winning, it's rigged when bts wins. show us the stats, data and numbers… https://t.co/mckBekia5U",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jiaelbe',
#      'name': 'JACKSON BEST ERAS📌 开♡༄',
#      'id': 1230470204041367552,
#      'id_str': '1230470204041367552',
#      'indices': [0, 8]}],
#    'urls': [{'url': 'https://t.co/mckBekia5U',
#      'expanded_url': 'https://twitter.com/i/web/status/1335432012795006976',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1335219760510939138,
#   'in_reply_to_status_id_str': '1335219760510939138',
#   'in_reply_to_user_id': 1230470204041367552,
#   'in_reply_to_user_id_str': '1230470204041367552',
#   'in_reply_to_screen_name': 'jiaelbe',
#   'user': {'id': 2937094094,
#    'id_str': '2937094094',
#    'name': 'den⁷ · busy📚',
#    'screen_name': 'outromnyg',
#    'location': 'she/her',
#    'description': '#YOONGI: the hand of midas & musical genius · fan account',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 452,
#    'friends_count': 321,
#    'listed_count': 26,
#    'created_at': 'Sat Dec 20 12:54:01 +0000 2014',
#    'favourites_count': 121294,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 116287,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1334862839572353025/vDUY7hQC_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334862839572353025/vDUY7hQC_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2937094094/1607091074',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 74,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 2,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
help(tweets[0])
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Returns a new dict with keys from iterable and values equal to value.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
tweets[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
tweets[0]['text']
# Out:
# "RT @outromnyg: @jiaelbe it's rigged when big3 groups stop winning, it's rigged when bts wins. show us the stats, data and numbers on why ya…"

# %%
tweets[0]['created_at']
# Out:
# 'Sun Dec 06 06:06:04 +0000 2020'

# %%
tweets[0]['text']
# Out:
# "RT @outromnyg: @jiaelbe it's rigged when big3 groups stop winning, it's rigged when bts wins. show us the stats, data and numbers on why ya…"

# %%
tweets[0]['user']
# Out:
# {'id': 1004232282985488384,
#  'id_str': '1004232282985488384',
#  'name': 'ᴮᴱAverie⁷',
#  'screen_name': 'spillxtheteasis',
#  'location': 'hell',
#  'description': 'armymoos follow me\U0001f92a\nif u know me irl no u dont\nshe/they',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 213,
#  'friends_count': 551,
#  'listed_count': 1,
#  'created_at': 'Wed Jun 06 05:23:28 +0000 2018',
#  'favourites_count': 60344,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 15814,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1334443759799418882/eoMxigKh_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334443759799418882/eoMxigKh_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1004232282985488384/1606991161',
#  'profile_link_color': 'F58EA8',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'has_extended_profile': True,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
user = tweets[0]['user']
print('screen_name=%s, name=%s, location=%s' % (user['screen_name'], user['name'], user['location']))
# Out:
# screen_name=spillxtheteasis, name=ᴮᴱAverie⁷, location=hell

# %%
# Who follows this person?
# https://dev.twitter.com/docs/api/1.1/get/followers/list
screen_name = user['screen_name']
response  = twitter.request('followers/list', {'screen_name': screen_name, 'count':200})
followers = [follower for follower in response]
        
print('found %d followers for %s' % (len(followers), screen_name))
# See more about paging here: https://dev.twitter.com/docs/working-with-timelines
# Out:
# found 200 followers for spillxtheteasis

# %%
print(followers[0]['screen_name'])
# Out:
# Knamjoonim

# %% [markdown]
# ##  Limitations:       Can only search 2 weeks in past         But can get up to 3,200 most recent tweets of a user     Rate limits! https://dev.twitter.com/docs/rate-limiting/1.1/limits         e.g., 180 requests in 15 minute window

# %% [markdown]
# # Get BestBuy timeline for the deals screen-name
#
# # This is the screen name for BestBuy_Deals

# %%
# Get BestBuyDeals timeline = ''
screen_name = 'amazon_grocery'
timeline = [tweet for tweet in twitter.request('statuses/user_timeline',
                                                {'screen_name': screen_name,
                                                 'count': 200})]
print('got %d tweets for user %s' % (len(timeline), screen_name))
# Out:
# got 200 tweets for user amazon_grocery

# %%
# Print time got created.

timeline[3]['created_at']
# Out:
# 'Tue May 15 11:45:17 +0000 2012'

# %%
# Print the text.
print('\n\n\n'.join(t['text'] for t in timeline))
# Out:
# Do you measure or throw in ingredients when baking?  http://t.co/SkjvqCyN
#
#
# Snap, Crackle, Pop - Gluten-Free Rice Krispies     http://t.co/4OXUueXK
#
#
# Check out our selection of gluten-free KIND bars     http://t.co/UD19x6Hq
#
#
# Bob's Red Mill Gluten-Free baking essentials.     http://t.co/n53Er5qJ
#
#
# Grocery Manager's Specials.      http://t.co/yYs4SDlq
#
#
# Breakfast bars up to 5% off.     http://t.co/tvf3Cu5P
#
#
# It's gluten-free month     http://t.co/okxXWGPo
#
#
# Celebrate National Pretzel Day with Amazon Everyday Low Prices    http://t.co/em7I3ZYs
#
#
# Check out our grocery Manager's Specials http://t.co/H0Qn0vWb
#
#
# What's your preference? Kashi cereal or Kashi bars?http://t.co/DGIdbHZr
#
#
#
#
# Tuscan Whole Milk - Such Hilarious Reviews - http://amzn.to/fVekpo - How much is this milk worth?
#
#
# $20 Off Nestea - http://amzn.to/fCLRL9 - Gold Box Lightning Deal  - Last 20 minutes
#
#
# Horizon Organic Milk : 18 packs for $13 - http://amzn.to/fsnIU4 - Lightning Deal - 2.5 Hours left
#
#
# Zico Coconut Water : Extra 20% Off - http://amzn.to/ijVYGY - Lightning Deal - 2 Hours left
#
#
# Stretch Island (Summer Strawberry) : Extra 20% Off - http://amzn.to/gZ5yBc - Lightning Deal - Only 3 Hours left
#
#
# Pirate's Booty : Extra 20% Off - http://amzn.to/epuXEB - Lightning Deal  - Only 3 Hours left
#
#
# @pgofhsm Hi PG. The credit reflects in 1-2 weeks to use for future purchase.
#
#
# Thanks to 16 RTs so far - The #1500 and 1 lucky RT wins - Let's get going. http://amzn.to/dTUhzk #amzngrogift
#
#
# Only 5 Hours Left--Friday Sale on 50 food items. http://amzn.to/hKwLfC . Stock up and tell your friends too. Happy weekend.
#
#
# Today Only--Friday Sale on 50 food items. http://amzn.to/hKwLfC . Tell your friends about these.
#
#
# With Love .. Valentine's Gift . Get us to #1500 foodie followers The #1500 and 1 lucky RT wins http://amzn.to/dTUhzk #amzngrogift
#
#
# Yogi Bear Hint Water - Extra 20% Off - http://amzn.to/dZAYfs - Lightning Deal @amazon_grocery - Only 2 Hours left
#
#
# 1940's Classic Candy Box - Extra $6 Off - http://amzn.to/hm63r5 - Lightning Deal @amazon_grocery - Only 2 Hours left
#
#
# Last 3 Days - Valentine's Gifts - Free 2-day shipping OR $5 credit (prime) : http://amzn.to/iaCr9d - @amazon_grocery
#
#
# #TuscanMilk The reviews are so Hilarious. Especially the first poem - http://amzn.to/hha4cc - @amazon_grocery
#
#
# @MomSpark Hats off to you. That's a perfect Mommy.
#
#
# Honey Bunches - $2 a box (use subscribe N save). Dropped prices just now. http://amzn.to/erAgFe. - @amazon_grocery
#
#
# Friday Sale on Starbucks, Herbal tea, Flavored Water.. http://bit.ly/dU6rgF. Tell your friends about these. - @amazon_grocery
#
#
# @dredpiratestone If the product goes out of stock they don't work till we are back in stock. Sorry about the sell out.
#
#
# Good Morning. Like these Granola Bars. Grab 6 packs of 12 for less than $10. Use code NATVALLY and SnS. http://amzn.to/eTk6H3
#
#
# @kwaterski We are a part of @amazon and @amazon_grocery delivers everywhere in WA. Are you in a different place
#
#
# @aaron_wheeler You will get a $5 credit around 02/18  to use for future purchase - @amazon_grocery
#
#
# @StJoesTechTeach We do ship everywhere. Infact recently we added Hawaii and Alaska. Its all online. http://amzn.to/cuDx8W
#
#
# Valentine's Gifts - Free 2-day shipping or $5 credit (for prime) : http://amzn.to/gubott - @amazon_grocery
#
#
# Hi, Our February promotions of up to 40% off are in : http://amzn.to/f3PAWp. Stock up now - @Amazon_Grocery
#
#
# @StJoesTechTeach Which town are you in.
#
#
# Great Cereals at less than $2 a box : http://amzn.to/fjmEwQ. Hurry up and also tell your friends - @Amazon_Grocery
#
#
# Friday Sale discounts on 50 products: http://amzn.to/6GaPJ6. One Day offer. Tell your friends about these discounts @amazon_grocery
#
#
# Save extra $4 on Silk SoyMilk: http://amzn.to/ifLqdu Lightning Deal-Valid through 10 AM PST
#
#
# Save extra $3 on YummyEarth Organic Lollipops: http://amzn.to/hXVspj Lightning Deal-Valid through 2 PM PST.
# - @amazon_grocery
#
#
# Enjoy Friday Sale special prices on coffee, tea, K-Cups, baby products, drink mixes, and more: http://amzn.to/6GaPJ6
# Offer valid only today
#
#
# Save an extra $6 on Jack Link's Beef Sticks: http://amzn.to/i4uujg
# Lightning Deal-Valid through 2 PM PST.

# %%
# Count words
from collections import Counter  # This is just a fancy dict mapping from object->int, starting at 0.
counts = Counter()
for tweet in timeline:
    counts.update(tweet['text'].lower().split())
print('found %d unique terms in %d tweets' % (len(counts), len(timeline)))
counts.most_common(10)
# Out:
# found 1152 unique terms in 200 tweets
# [('-', 124),
#  ('off', 72),
#  ('and', 62),
#  ('to', 56),
#  ('up', 52),
#  ('the', 44),
#  ('on', 42),
#  ('extra', 41),
#  ('save', 39),
#  ('25%', 35)]

# %%
import re
for tweet in timeline:
    deal = tweet['text']
    print(deal + '\n')
# Out:
# Do you measure or throw in ingredients when baking?  http://t.co/SkjvqCyN
#
# Snap, Crackle, Pop - Gluten-Free Rice Krispies     http://t.co/4OXUueXK
#
# Check out our selection of gluten-free KIND bars     http://t.co/UD19x6Hq
#
# Bob's Red Mill Gluten-Free baking essentials.     http://t.co/n53Er5qJ
#
# Grocery Manager's Specials.      http://t.co/yYs4SDlq
#
# Breakfast bars up to 5% off.     http://t.co/tvf3Cu5P
#
# It's gluten-free month     http://t.co/okxXWGPo
#
# Celebrate National Pretzel Day with Amazon Everyday Low Prices    http://t.co/em7I3ZYs
#
# Check out our grocery Manager's Specials http://t.co/H0Qn0vWb
#
# What's your preference? Kashi cereal or Kashi bars?http://t.co/DGIdbHZr
#
# If you could only eat one cereal for the rest of your life, what would it be? http://t.co/dp5Zp7wn
#
# Up to 25% off trail mix. http://t.co/GOw4NjVw
#
# Up to 35% Off Breakfast Bars http://t.co/Ti4fe87F
#
# Up to 35% off Kashi. http://t.co/AgR0q093
#
# Say goodbye to boring tea. http://t.co/o1QQHMJp
#
# Try organic meal replacement drinks.  Up to 20% off. http://t.co/sw5cREPl
#
# Switch up your oatmeal routine and try Oatmeal Squares Cereal. http://t.co/qeQaTTqO
#
# Get the perfect cup of coffee with K-Cups. Up to 15% Off. http://t.co/Of25M8iR
#
# Up to 15% off Splenda with Subscribe & Save. http://t.co/bduOQKe9
#
# Kick start your morning with Quaker cereal and save. http://t.co/8NT0kU3N
#
# Help fight off that sick feeling and save on Tea up to 20% off. http://t.co/ZhcBr76w
#
# Ummm...chocolate http://t.co/8YeZMmF5
#
# Be that guy and send her flowers.  Order online and save. http://t.co/vUguLemQ
#
# Feb Grocery savings event.  Check it out. http://t.co/ZQPjL4Qq
#
# Whip up a culinary masterpiece with Zoe! http://t.co/gLjGvxHI
#
# thinkThink bars: perfect for the active, on-the-go lifestyle. http://t.co/OZScqkhr
#
# Honey Bunches - $2 a box (use subscribe N save). Dropped prices just now. http://amzn.to/erAgFe. - @amazon_grocery
#
# Friday Sale on Starbucks, Herbal tea, Flavored Water.. http://bit.ly/dU6rgF. Tell your friends about these. - @amazon_grocery
#
# @dredpiratestone If the product goes out of stock they don't work till we are back in stock. Sorry about the sell out.
#
# Good Morning. Like these Granola Bars. Grab 6 packs of 12 for less than $10. Use code NATVALLY and SnS. http://amzn.to/eTk6H3
#
# @kwaterski We are a part of @amazon and @amazon_grocery delivers everywhere in WA. Are you in a different place
#
# @aaron_wheeler You will get a $5 credit around 02/18  to use for future purchase - @amazon_grocery
#
# @StJoesTechTeach We do ship everywhere. Infact recently we added Hawaii and Alaska. Its all online. http://amzn.to/cuDx8W
#
# Valentine's Gifts - Free 2-day shipping or $5 credit (for prime) : http://amzn.to/gubott - @amazon_grocery
#
# Hi, Our February promotions of up to 40% off are in : http://amzn.to/f3PAWp. Stock up now - @Amazon_Grocery
#
# @StJoesTechTeach Which town are you in.
#
# Great Cereals at less than $2 a box : http://amzn.to/fjmEwQ. Hurry up and also tell your friends - @Amazon_Grocery
#
# Friday Sale discounts on 50 products: http://amzn.to/6GaPJ6. One Day offer. Tell your friends about these discounts @amazon_grocery
#
# Save extra $4 on Silk SoyMilk: http://amzn.to/ifLqdu Lightning Deal-Valid through 10 AM PST
#
# Save extra $3 on YummyEarth Organic Lollipops: http://amzn.to/hXVspj Lightning Deal-Valid through 2 PM PST.
# - @amazon_grocery
#
# Enjoy Friday Sale special prices on coffee, tea, K-Cups, baby products, drink mixes, and more: http://amzn.to/6GaPJ6
# Offer valid only today
#
# Save an extra $6 on Jack Link's Beef Sticks: http://amzn.to/i4uujg
# Lightning Deal-Valid through 2 PM PST.

# %% [markdown]
# # Find  the deals in the BestBuy_Deal tweets  that match products in SmartPortables MySQL product table

# %%
import re
import pymysql

cnx = pymysql.connect(user='root', password='Ilovemyself',
                              host='127.0.0.1',
                              database='groceryhub')
cursor = cnx.cursor()

query = ("SELECT productId FROM productdetails")
cursor.execute(query)
results = cursor.fetchall()


dealMatchGauranteed=[]
for product in results:
    for tweet in timeline:
        deal = (tweet['text'])
        if (len(re.findall('\s'+product[0]+'\s',deal)) >= 1):
            dealMatchGauranteed = dealMatchGauranteed + [deal]

# %%
# Sanity Test that  we got some deals
dealMatchGauranteed[:5]
# Out:
# ["What's your preference? Kashi cereal or Kashi bars?http://t.co/DGIdbHZr",
#  'If you could only eat one cereal for the rest of your life, what would it be? http://t.co/dp5Zp7wn',
#  'Kick start your morning with Quaker cereal and save. http://t.co/8NT0kU3N',
#  'Get the perfect cup of coffee with K-Cups. Up to 15% Off. http://t.co/Of25M8iR',
#  'Lot of coffee and tea on one day sale - http://amzn.to/gvD4Ur']

# %% [markdown]
# # Create and write the deals into DealMatches.txt file that will be used by web-app of SmartPortables to display two deal matches

# %%
dealMatchFile = open(r'C:\apache-tomcat-7.0.34\webapps\Assignment_5\DealMatches.txt', 'w')
for deal in dealMatchGauranteed:
    dealMatchFile.write("%s\n" % deal)

dealMatchFile.close()
